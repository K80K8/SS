# %%
# python 3.8.10 environment
import pandas as pd
import numpy as np
import glob
import os

# %%
# file_paths = ['list_data.txt']
folder_path = "."

# Get all .txt files in the folder
file_paths = glob.glob(os.path.join(folder_path, "*vol*.txt"))

dfs = []
for i, path in enumerate(file_paths):
    if i == 0:
        df = pd.read_csv(path, sep=',')
    else:
        df = pd.read_csv(path, sep=',', skiprows=1, header=None)
        df.columns = dfs[0].columns
    dfs.append(df)

df_combined = pd.concat(dfs, ignore_index=True)

print(df_combined)
# Out:
#    ForSystem   Barcode             Manufacturer                      Model  \
# 0          1  Barcode1  ASUSTeK COMPUTER INC.    ROG Strix G513IE_G513IE
# 1          1  Barcode2  ASUSTeK COMPUTER INC.    ROG Strix G513IE_G513IE
# 2          0     List1  ASUSTeK COMPUTER INC.    ROG Strix G513IE_G513IE
# 3          1  Barcode3  ASUSTeK COMPUTER INC.    ROG Strix G513IE_G513IE
# 4          0     List2  ASUSTeK COMPUTER INC.    ROG Strix G513IE_G513IE
# 5          0     List3  ASUSTeK COMPUTER INC.    ROG Strix G513IE_G513IE
#
#         SerialNumber                                       CPU  CPUCores  \
# 0  N3NRKD03324310B    AMD Ryzen 7 4800H with Radeon Graphics           8
# 1  N3NRKD03324310B    AMD Ryzen 7 4800H with Radeon Graphics           8
# 2  N3NRKD03324310B    AMD Ryzen 7 4800H with Radeon Graphics           8
# 3  N3NRKD03324310B    AMD Ryzen 7 4800H with Radeon Graphics           8
# 4  N3NRKD03324310B    AMD Ryzen 7 4800H with Radeon Graphics           8
# 5  N3NRKD03324310B    AMD Ryzen 7 4800H with Radeon Graphics           8
#
#      RAMAmount  RAMType  StorageAmount StorageType CorporateSupplier  \
# 0  16558182400       26   512105932800   SSD                    Test
# 1  16558182400       26   512105932800   SSD                     NaN
# 2  16558182400       26   512105932800   SSD                     NaN
# 3  16558182400       26   512105932800   SSD                   Test2
# 4  16558182400       26   512105932800   SSD                     NaN
# 5  16558182400       26   512105932800   SSD                     NaN
#
#                        Windows                       WindowsActivated
# 0  Microsoft Windows 11 Home    The machine is permanently activated.
# 1  Microsoft Windows 11 Home    The machine is permanently activated.
# 2  Microsoft Windows 11 Home    The machine is permanently activated.
# 3  Microsoft Windows 11 Home    The machine is permanently activated.
# 4  Microsoft Windows 11 Home    The machine is permanently activated.
# 5  Microsoft Windows 11 Home    The machine is permanently activated.

# %%
# Convert bytes to GB, always rounding UP, and format with 'GB'
df_combined['RAM'] = (np.ceil(df_combined['RAMAmount'] / (1024**3))).astype(int).astype(str) + 'GB'
df_combined.drop('RAMAmount', axis=1)
# Out:
#    ForSystem   Barcode             Manufacturer                      Model  \
# 0          1  Barcode1  ASUSTeK COMPUTER INC.    ROG Strix G513IE_G513IE
# 1          1  Barcode2  ASUSTeK COMPUTER INC.    ROG Strix G513IE_G513IE
# 2          0     List1  ASUSTeK COMPUTER INC.    ROG Strix G513IE_G513IE
# 3          1  Barcode3  ASUSTeK COMPUTER INC.    ROG Strix G513IE_G513IE
# 4          0     List2  ASUSTeK COMPUTER INC.    ROG Strix G513IE_G513IE
# 5          0     List3  ASUSTeK COMPUTER INC.    ROG Strix G513IE_G513IE
#
#         SerialNumber                                       CPU  CPUCores  \
# 0  N3NRKD03324310B    AMD Ryzen 7 4800H with Radeon Graphics           8
# 1  N3NRKD03324310B    AMD Ryzen 7 4800H with Radeon Graphics           8
# 2  N3NRKD03324310B    AMD Ryzen 7 4800H with Radeon Graphics           8
# 3  N3NRKD03324310B    AMD Ryzen 7 4800H with Radeon Graphics           8
# 4  N3NRKD03324310B    AMD Ryzen 7 4800H with Radeon Graphics           8
# 5  N3NRKD03324310B    AMD Ryzen 7 4800H with Radeon Graphics           8
#
#    RAMType  StorageAmount StorageType CorporateSupplier  \
# 0       26   512105932800   SSD                    Test
# 1       26   512105932800   SSD                     NaN
# 2       26   512105932800   SSD                     NaN
# 3       26   512105932800   SSD                   Test2
# 4       26   512105932800   SSD                     NaN
# 5       26   512105932800   SSD                     NaN
#
#                        Windows                       WindowsActivated   RAM
# 0  Microsoft Windows 11 Home    The machine is permanently activated.  16GB
# 1  Microsoft Windows 11 Home    The machine is permanently activated.  16GB
# 2  Microsoft Windows 11 Home    The machine is permanently activated.  16GB
# 3  Microsoft Windows 11 Home    The machine is permanently activated.  16GB
# 4  Microsoft Windows 11 Home    The machine is permanently activated.  16GB
# 5  Microsoft Windows 11 Home    The machine is permanently activated.  16GB

# %%
# Define RAM lookup table
ram_lookup_table = {
    0: "Unknown",
    1: "Other",
    2: "DRAM",
    3: "Synchronous DRAM",
    4: "Cache DRAM",
    5: "EDO",
    6: "EDRAM",
    7: "VRAM",
    8: "SRAM",
    9: "RAM",
    10: "ROM",
    11: "Flash",
    12: "EEPROM",
    13: "FEPROM",
    14: "EPROM",
    15: "CDRAM",
    16: "3DRAM",
    17: "SDRAM",
    18: "SGRAM",
    19: "RDRAM",
    20: "DDR",
    21: "DDR2",
    22: "DDR2 FB-DIMM",
    23: "Reserved",
    24: "DDR3",
    25: "FBD2",
    26: "DDR4",
    27: "LPDDR",
    28: "LPDDR2",
    29: "LPDDR3",
    30: "LPDDR4",
    31: "Logical non-volatile device",
    32: "HBM",
    33: "HBM2",
    34: "DDR5"
}

# %%
# Map the numeric codes to names and add to new column for ram amount and type
df_combined['RAM Amount and Type'] = df_combined['RAM'] + ' ' + df_combined['RAMType'].map(ram_lookup_table)


# List of columns to drop
columns_to_drop = ['RAM', 'RAMType', 'RAMAmount']

# Drop multiple columns
df_new = df_combined.drop(columns=columns_to_drop)
print(df_new)
# Out:
#    ForSystem   Barcode             Manufacturer                      Model  \
# 0          1  Barcode1  ASUSTeK COMPUTER INC.    ROG Strix G513IE_G513IE
# 1          1  Barcode2  ASUSTeK COMPUTER INC.    ROG Strix G513IE_G513IE
# 2          0     List1  ASUSTeK COMPUTER INC.    ROG Strix G513IE_G513IE
# 3          1  Barcode3  ASUSTeK COMPUTER INC.    ROG Strix G513IE_G513IE
# 4          0     List2  ASUSTeK COMPUTER INC.    ROG Strix G513IE_G513IE
# 5          0     List3  ASUSTeK COMPUTER INC.    ROG Strix G513IE_G513IE
#
#         SerialNumber                                       CPU  CPUCores  \
# 0  N3NRKD03324310B    AMD Ryzen 7 4800H with Radeon Graphics           8
# 1  N3NRKD03324310B    AMD Ryzen 7 4800H with Radeon Graphics           8
# 2  N3NRKD03324310B    AMD Ryzen 7 4800H with Radeon Graphics           8
# 3  N3NRKD03324310B    AMD Ryzen 7 4800H with Radeon Graphics           8
# 4  N3NRKD03324310B    AMD Ryzen 7 4800H with Radeon Graphics           8
# 5  N3NRKD03324310B    AMD Ryzen 7 4800H with Radeon Graphics           8
#
#    StorageAmount StorageType CorporateSupplier                      Windows  \
# 0   512105932800   SSD                    Test  Microsoft Windows 11 Home
# 1   512105932800   SSD                     NaN  Microsoft Windows 11 Home
# 2   512105932800   SSD                     NaN  Microsoft Windows 11 Home
# 3   512105932800   SSD                   Test2  Microsoft Windows 11 Home
# 4   512105932800   SSD                     NaN  Microsoft Windows 11 Home
# 5   512105932800   SSD                     NaN  Microsoft Windows 11 Home
#
#                         WindowsActivated RAM Amount and Type
# 0  The machine is permanently activated.           16GB DDR4
# 1  The machine is permanently activated.           16GB DDR4
# 2  The machine is permanently activated.           16GB DDR4
# 3  The machine is permanently activated.           16GB DDR4
# 4  The machine is permanently activated.           16GB DDR4
# 5  The machine is permanently activated.           16GB DDR4

# %%
# Convert bytes to GB
sizes_gb = df_new['StorageAmount'] / (1024**3)

# Common marketed capacities in GB
common_sizes = np.array([64, 128, 256, 512, 1024, 2048, 4096])

# Snap each size to nearest common capacity
def snap_to_common(x):
    return common_sizes[np.argmin(np.abs(common_sizes - x))]

df_new['Storage_Snapped_GB'] = sizes_gb.apply(snap_to_common)

# Format as string with GB or TB
def format_size(x):
    if x >= 1024:
        return f"{int(x/1024)}TB"
    else:
        return f"{int(x)}GB"

df_new['Storage_Display'] = df_new['Storage_Snapped_GB'].apply(format_size)
df_new['Storage Amount and Type'] = df_new['Storage_Display'] + ' ' + df_new['StorageType']

# %%
# List of columns to drop
columns_to_drop = ['StorageAmount', 'StorageType', 'Storage_Snapped_GB', 'Storage_Display']

# Drop multiple columns
df_newer = df_new.drop(columns=columns_to_drop)

print(df_newer)
# Out:
#    ForSystem   Barcode             Manufacturer                      Model  \
# 0          1  Barcode1  ASUSTeK COMPUTER INC.    ROG Strix G513IE_G513IE
# 1          1  Barcode2  ASUSTeK COMPUTER INC.    ROG Strix G513IE_G513IE
# 2          0     List1  ASUSTeK COMPUTER INC.    ROG Strix G513IE_G513IE
# 3          1  Barcode3  ASUSTeK COMPUTER INC.    ROG Strix G513IE_G513IE
# 4          0     List2  ASUSTeK COMPUTER INC.    ROG Strix G513IE_G513IE
# 5          0     List3  ASUSTeK COMPUTER INC.    ROG Strix G513IE_G513IE
#
#         SerialNumber                                       CPU  CPUCores  \
# 0  N3NRKD03324310B    AMD Ryzen 7 4800H with Radeon Graphics           8
# 1  N3NRKD03324310B    AMD Ryzen 7 4800H with Radeon Graphics           8
# 2  N3NRKD03324310B    AMD Ryzen 7 4800H with Radeon Graphics           8
# 3  N3NRKD03324310B    AMD Ryzen 7 4800H with Radeon Graphics           8
# 4  N3NRKD03324310B    AMD Ryzen 7 4800H with Radeon Graphics           8
# 5  N3NRKD03324310B    AMD Ryzen 7 4800H with Radeon Graphics           8
#
#   CorporateSupplier                      Windows  \
# 0              Test  Microsoft Windows 11 Home
# 1               NaN  Microsoft Windows 11 Home
# 2               NaN  Microsoft Windows 11 Home
# 3             Test2  Microsoft Windows 11 Home
# 4               NaN  Microsoft Windows 11 Home
# 5               NaN  Microsoft Windows 11 Home
#
#                         WindowsActivated RAM Amount and Type  \
# 0  The machine is permanently activated.           16GB DDR4
# 1  The machine is permanently activated.           16GB DDR4
# 2  The machine is permanently activated.           16GB DDR4
# 3  The machine is permanently activated.           16GB DDR4
# 4  The machine is permanently activated.           16GB DDR4
# 5  The machine is permanently activated.           16GB DDR4
#
#   Storage Amount and Type
# 0         512GB SSD
# 1         512GB SSD
# 2         512GB SSD
# 3         512GB SSD
# 4         512GB SSD
# 5         512GB SSD

# %%
df_newer = df_newer.fillna('')
df_converted = df_newer.astype(str)
print(df_converted)
# Out:
#   ForSystem   Barcode             Manufacturer                      Model  \
# 0         1  Barcode1  ASUSTeK COMPUTER INC.    ROG Strix G513IE_G513IE
# 1         1  Barcode2  ASUSTeK COMPUTER INC.    ROG Strix G513IE_G513IE
# 2         0     List1  ASUSTeK COMPUTER INC.    ROG Strix G513IE_G513IE
# 3         1  Barcode3  ASUSTeK COMPUTER INC.    ROG Strix G513IE_G513IE
# 4         0     List2  ASUSTeK COMPUTER INC.    ROG Strix G513IE_G513IE
# 5         0     List3  ASUSTeK COMPUTER INC.    ROG Strix G513IE_G513IE
#
#         SerialNumber                                       CPU CPUCores  \
# 0  N3NRKD03324310B    AMD Ryzen 7 4800H with Radeon Graphics          8
# 1  N3NRKD03324310B    AMD Ryzen 7 4800H with Radeon Graphics          8
# 2  N3NRKD03324310B    AMD Ryzen 7 4800H with Radeon Graphics          8
# 3  N3NRKD03324310B    AMD Ryzen 7 4800H with Radeon Graphics          8
# 4  N3NRKD03324310B    AMD Ryzen 7 4800H with Radeon Graphics          8
# 5  N3NRKD03324310B    AMD Ryzen 7 4800H with Radeon Graphics          8
#
#   CorporateSupplier                      Windows  \
# 0              Test  Microsoft Windows 11 Home
# 1                    Microsoft Windows 11 Home
# 2                    Microsoft Windows 11 Home
# 3             Test2  Microsoft Windows 11 Home
# 4                    Microsoft Windows 11 Home
# 5                    Microsoft Windows 11 Home
#
#                         WindowsActivated RAM Amount and Type  \
# 0  The machine is permanently activated.           16GB DDR4
# 1  The machine is permanently activated.           16GB DDR4
# 2  The machine is permanently activated.           16GB DDR4
# 3  The machine is permanently activated.           16GB DDR4
# 4  The machine is permanently activated.           16GB DDR4
# 5  The machine is permanently activated.           16GB DDR4
#
#   Storage Amount and Type
# 0         512GB SSD
# 1         512GB SSD
# 2         512GB SSD
# 3         512GB SSD
# 4         512GB SSD
# 5         512GB SSD

# %%
df_converted.insert(loc=0, column='ID', value=None) # can change value
print(df_converted)
# Out:
#      ID ForSystem   Barcode             Manufacturer  \
# 0  None         1  Barcode1  ASUSTeK COMPUTER INC.
# 1  None         1  Barcode2  ASUSTeK COMPUTER INC.
# 2  None         0     List1  ASUSTeK COMPUTER INC.
# 3  None         1  Barcode3  ASUSTeK COMPUTER INC.
# 4  None         0     List2  ASUSTeK COMPUTER INC.
# 5  None         0     List3  ASUSTeK COMPUTER INC.
#
#                        Model       SerialNumber  \
# 0  ROG Strix G513IE_G513IE    N3NRKD03324310B
# 1  ROG Strix G513IE_G513IE    N3NRKD03324310B
# 2  ROG Strix G513IE_G513IE    N3NRKD03324310B
# 3  ROG Strix G513IE_G513IE    N3NRKD03324310B
# 4  ROG Strix G513IE_G513IE    N3NRKD03324310B
# 5  ROG Strix G513IE_G513IE    N3NRKD03324310B
#
#                                         CPU CPUCores CorporateSupplier  \
# 0  AMD Ryzen 7 4800H with Radeon Graphics          8              Test
# 1  AMD Ryzen 7 4800H with Radeon Graphics          8
# 2  AMD Ryzen 7 4800H with Radeon Graphics          8
# 3  AMD Ryzen 7 4800H with Radeon Graphics          8             Test2
# 4  AMD Ryzen 7 4800H with Radeon Graphics          8
# 5  AMD Ryzen 7 4800H with Radeon Graphics          8
#
#                        Windows                       WindowsActivated  \
# 0  Microsoft Windows 11 Home    The machine is permanently activated.
# 1  Microsoft Windows 11 Home    The machine is permanently activated.
# 2  Microsoft Windows 11 Home    The machine is permanently activated.
# 3  Microsoft Windows 11 Home    The machine is permanently activated.
# 4  Microsoft Windows 11 Home    The machine is permanently activated.
# 5  Microsoft Windows 11 Home    The machine is permanently activated.
#
#   RAM Amount and Type Storage Amount and Type
# 0           16GB DDR4         512GB SSD
# 1           16GB DDR4         512GB SSD
# 2           16GB DDR4         512GB SSD
# 3           16GB DDR4         512GB SSD
# 4           16GB DDR4         512GB SSD
# 5           16GB DDR4         512GB SSD

# %%
for col in df_converted.select_dtypes(include=['object']).columns:
    df_converted[col] = df_converted[col].str.strip()
print(df_converted)
# Out:
#      ID ForSystem   Barcode           Manufacturer                    Model  \
# 0  None         1  Barcode1  ASUSTeK COMPUTER INC.  ROG Strix G513IE_G513IE
# 1  None         1  Barcode2  ASUSTeK COMPUTER INC.  ROG Strix G513IE_G513IE
# 2  None         0     List1  ASUSTeK COMPUTER INC.  ROG Strix G513IE_G513IE
# 3  None         1  Barcode3  ASUSTeK COMPUTER INC.  ROG Strix G513IE_G513IE
# 4  None         0     List2  ASUSTeK COMPUTER INC.  ROG Strix G513IE_G513IE
# 5  None         0     List3  ASUSTeK COMPUTER INC.  ROG Strix G513IE_G513IE
#
#       SerialNumber                                     CPU CPUCores  \
# 0  N3NRKD03324310B  AMD Ryzen 7 4800H with Radeon Graphics        8
# 1  N3NRKD03324310B  AMD Ryzen 7 4800H with Radeon Graphics        8
# 2  N3NRKD03324310B  AMD Ryzen 7 4800H with Radeon Graphics        8
# 3  N3NRKD03324310B  AMD Ryzen 7 4800H with Radeon Graphics        8
# 4  N3NRKD03324310B  AMD Ryzen 7 4800H with Radeon Graphics        8
# 5  N3NRKD03324310B  AMD Ryzen 7 4800H with Radeon Graphics        8
#
#   CorporateSupplier                    Windows  \
# 0              Test  Microsoft Windows 11 Home
# 1                    Microsoft Windows 11 Home
# 2                    Microsoft Windows 11 Home
# 3             Test2  Microsoft Windows 11 Home
# 4                    Microsoft Windows 11 Home
# 5                    Microsoft Windows 11 Home
#
#                         WindowsActivated RAM Amount and Type  \
# 0  The machine is permanently activated.           16GB DDR4
# 1  The machine is permanently activated.           16GB DDR4
# 2  The machine is permanently activated.           16GB DDR4
# 3  The machine is permanently activated.           16GB DDR4
# 4  The machine is permanently activated.           16GB DDR4
# 5  The machine is permanently activated.           16GB DDR4
#
#   Storage Amount and Type
# 0               512GB SSD
# 1               512GB SSD
# 2               512GB SSD
# 3               512GB SSD
# 4               512GB SSD
# 5               512GB SSD

# %%
# Only keep first 4 words for Ryzen
keyword = 'AMD Ryzen'
mask = df_converted['CPU'].str.contains(keyword, case=False, na=False)

df_converted['CPU'] = df_converted.apply(
    lambda row: ' '.join(row['CPU'].split()[:4]) if mask[row.name] else row['CPU'],
    axis=1
)
# Out:
#      ID ForSystem   Barcode           Manufacturer                    Model  \
# 0  None         1  Barcode1  ASUSTeK COMPUTER INC.  ROG Strix G513IE_G513IE
# 1  None         1  Barcode2  ASUSTeK COMPUTER INC.  ROG Strix G513IE_G513IE
# 2  None         0     List1  ASUSTeK COMPUTER INC.  ROG Strix G513IE_G513IE
# 3  None         1  Barcode3  ASUSTeK COMPUTER INC.  ROG Strix G513IE_G513IE
# 4  None         0     List2  ASUSTeK COMPUTER INC.  ROG Strix G513IE_G513IE
# 5  None         0     List3  ASUSTeK COMPUTER INC.  ROG Strix G513IE_G513IE
#
#       SerialNumber                CPU CPUCores CorporateSupplier  \
# 0  N3NRKD03324310B  AMD Ryzen 7 4800H        8              Test
# 1  N3NRKD03324310B  AMD Ryzen 7 4800H        8
# 2  N3NRKD03324310B  AMD Ryzen 7 4800H        8
# 3  N3NRKD03324310B  AMD Ryzen 7 4800H        8             Test2
# 4  N3NRKD03324310B  AMD Ryzen 7 4800H        8
# 5  N3NRKD03324310B  AMD Ryzen 7 4800H        8
#
#                      Windows                       WindowsActivated  \
# 0  Microsoft Windows 11 Home  The machine is permanently activated.
# 1  Microsoft Windows 11 Home  The machine is permanently activated.
# 2  Microsoft Windows 11 Home  The machine is permanently activated.
# 3  Microsoft Windows 11 Home  The machine is permanently activated.
# 4  Microsoft Windows 11 Home  The machine is permanently activated.
# 5  Microsoft Windows 11 Home  The machine is permanently activated.
#
#   RAM Amount and Type Storage Amount and Type
# 0           16GB DDR4               512GB SSD
# 1           16GB DDR4               512GB SSD
# 2           16GB DDR4               512GB SSD
# 3           16GB DDR4               512GB SSD
# 4           16GB DDR4               512GB SSD
# 5           16GB DDR4               512GB SSD

# %%
# Replace Intel(R) Core(TM) with Intel Core and keep the next word (model)
df_converted['CPU'] = df_converted['CPU'].str.replace(
    r'.*Intel\(R\) Core\(TM\)\s+(\S+).*',
    r'Intel Core \1',
    regex=True
)
print(df_converted)

# %%
df_converted['CPU'] = df_converted['CPU'] + ' ' + df_converted['CPUCores'] + ' Core Processor'
df = df_converted.drop('CPUCores', axis=1)
print(df)
# Out:
#      ID ForSystem   Barcode           Manufacturer                    Model  \
# 0  None         1  Barcode1  ASUSTeK COMPUTER INC.  ROG Strix G513IE_G513IE
# 1  None         1  Barcode2  ASUSTeK COMPUTER INC.  ROG Strix G513IE_G513IE
# 2  None         0     List1  ASUSTeK COMPUTER INC.  ROG Strix G513IE_G513IE
# 3  None         1  Barcode3  ASUSTeK COMPUTER INC.  ROG Strix G513IE_G513IE
# 4  None         0     List2  ASUSTeK COMPUTER INC.  ROG Strix G513IE_G513IE
# 5  None         0     List3  ASUSTeK COMPUTER INC.  ROG Strix G513IE_G513IE
#
#       SerialNumber                                 CPU CorporateSupplier  \
# 0  N3NRKD03324310B  AMD Ryzen 7 4800H 8 Core Processor              Test
# 1  N3NRKD03324310B  AMD Ryzen 7 4800H 8 Core Processor               nan
# 2  N3NRKD03324310B  AMD Ryzen 7 4800H 8 Core Processor               nan
# 3  N3NRKD03324310B  AMD Ryzen 7 4800H 8 Core Processor             Test2
# 4  N3NRKD03324310B  AMD Ryzen 7 4800H 8 Core Processor               nan
# 5  N3NRKD03324310B  AMD Ryzen 7 4800H 8 Core Processor               nan
#
#                      Windows                       WindowsActivated  \
# 0  Microsoft Windows 11 Home  The machine is permanently activated.
# 1  Microsoft Windows 11 Home  The machine is permanently activated.
# 2  Microsoft Windows 11 Home  The machine is permanently activated.
# 3  Microsoft Windows 11 Home  The machine is permanently activated.
# 4  Microsoft Windows 11 Home  The machine is permanently activated.
# 5  Microsoft Windows 11 Home  The machine is permanently activated.
#
#   RAM Amount and Type Storage Amount and Type
# 0           16GB DDR4               512GB SSD
# 1           16GB DDR4               512GB SSD
# 2           16GB DDR4               512GB SSD
# 3           16GB DDR4               512GB SSD
# 4           16GB DDR4               512GB SSD
# 5           16GB DDR4               512GB SSD

# %%
df['Windows Type and Version'] = df['Windows']
df = df.drop('Windows', axis=1)
print(df)

# %%
# Replace 'y' with 'Yes' and 'n' with 'No' in Windows Activated
df['Is Windows Activated?'] = df['WindowsActivated'].replace({'The machine is permanently activated. ': 'Yes', 'n': 'No'})
df = df.drop('WindowsActivated', axis=1)
print(df)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/.local/lib/python3.8/site-packages/pandas/core/indexes/base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File ~/.local/lib/python3.8/site-packages/pandas/_libs/index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/.local/lib/python3.8/site-packages/pandas/_libs/index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'WindowsActivated'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Input In [24], in <cell line: 2>()
#       1 # Replace 'y' with 'Yes' and 'n' with 'No' in Windows Activated
# ----> 2 df['Is Windows Activated?'] = df['WindowsActivated'].replace({'The machine is permanently activated. ': 'Yes', 'n': 'No'})
#       3 df = df.drop('WindowsActivated', axis=1)
#       4 print(df)
#
# File ~/.local/lib/python3.8/site-packages/pandas/core/frame.py:3505, in DataFrame.__getitem__(self, key)
#    3503 if self.columns.nlevels > 1:
#    3504     return self._getitem_multilevel(key)
# -> 3505 indexer = self.columns.get_loc(key)
#    3506 if is_integer(indexer):
#    3507     indexer = [indexer]
#
# File ~/.local/lib/python3.8/site-packages/pandas/core/indexes/base.py:3623, in Index.get_loc(self, key, method, tolerance)
#    3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
# -> 3623     raise KeyError(key) from err
#    3624 except TypeError:
#    3625     # If we have a listlike key, _check_indexing_error will raise
#    3626     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3627     #  the TypeError.
#    3628     self._check_indexing_error(key)
#
# KeyError: 'WindowsActivated'

# %%
df.to_csv('output_listed.csv', index=False)
